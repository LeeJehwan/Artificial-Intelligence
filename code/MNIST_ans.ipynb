# %% [markdown]
# # MNIST

# %% [markdown]
# ### MNIST 데이터 받기

# %%
import os
import sys
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("data/", one_hot=True)
train_data = mnist.train.images
train_label = mnist.train.labels
test_data = mnist.test.images
test_label = mnist.test.labels
# Out:
# WARNING:tensorflow:From <ipython-input-1-76cba88990fd>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/mlg/ny/lstm/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/mlg/ny/lstm/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/mlg/ny/lstm/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/mlg/ny/lstm/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/mlg/ny/lstm/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ### MNIST 데이터 확인하기

# %%
# size of MNIST
print(train_data.shape)
print(train_label.shape)
print(test_data.shape)
print(test_label.shape)
# Out:
# (55000, 784)
# (55000, 10)
# (10000, 784)
# (10000, 10)

# %% [markdown]
# ### Data Pre-processing (데이터 전처리)

# %% [markdown]
# # Implementation (1)
#
#
# ## Loss function (손실 함수) : Cross Entropy
#
# # <center> \\( L(y, f(x; W)) = -\frac{1}{n}\sum_{i=1}^{n}\sum_{k=1} y_{i,j} log(f(x_i)_k)\\)</center>
#
#
# #### get_cross_entropy_loss 함수의 내용을 완성하세요.
# #### (Hint : (1) tf.reduce_mean(), tf.reduce_sum(), tf.log() (2) Tensor dimension에 유의 (3) log 함수 사용 시 epsilon 사용하세요.)

# %%
def get_accuracy(y_true, y_hat):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('accuracy'):
        # Compare the highest indices between the predicted label and the true label
        correct_prediction = tf.equal(tf.argmax(y_hat, 1), tf.argmax(y_true, 1), name='correct_prediction')
        # Compute accuracy
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')
    return accuracy

# %%
def get_cross_entropy_loss(y_true, y_hat, epsilon=1e-8):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('cross_entropy'):
        loss= -tf.reduce_mean(tf.reduce_sum(y_true * tf.log(y_hat), axis=1))
    return loss

# y_true=tf.placeholder(tf.float32, [None, 10])
# y_hat=tf.placeholder(tf.float32, [None, 10])
# get_cross_entropy_loss(y_true, y_hat)

# %% [markdown]
# ## Hyper-parameter (하이퍼 파라미터)

# %%
# Set hypyerparameters
learning_rate = 0.01
max_iter = 2000
batch_size = 100

# %% [markdown]
# # Implementation (2)
# ## Linear Classifier (선형 분류기)
#
# ## <center> \\( f(x) = W^Tx+b \\)</center>
#
# ### linear function을 완성하세요.
# ### (Hint : (1) weight, bias 선언 (2) tf.get_variable()의 initializer  (3) tf.matmul())

# %%
def fc(name, out_dim, inputs):
    """
    Args :
        Inputs : Input tensor
        out_dim : output dimension
        
    Returns:
        inputs * weight + bias
    """
    with tf.variable_scope(name):
        shp = inputs.get_shape().as_list()[1]
        initial = tf.truncated_normal([shp, out_dim], stddev=.01)
        weights = tf.get_variable('w', initializer=initial)
        y_hat = tf.matmul(inputs, weights)
        return y_hat

# %% [markdown]
# # Implementation (3)
#
# ## Model Setting
#
# ### 1. Training data 및 Test data의 각각의 image를 한 vector로 만들어서 train_data, test_data에 각각 저장하세요.
# #### Hint) 데이터 차원.
# ### 2. Dataset로부터 받은 데이터(Image, label)를 담을 변수를 각각 x 및 y_true에 선언하세요.
# #### Hint) tf.placeholder
# ### 3. Implementation (2)에서 구현한 linear classifier 함수값과 softmax 함수를 통한 prediction 값을 y_hat에 저장하세요.
# #### Hint) tf.nn.softmax
# ### 4. 3으로부터 얻은 결과를 통해 Implementation (1)에서 구현한 loss function을 통해 얻은 loss를 cross_entropy에 저장하세요.

# %%
tf.reset_default_graph()
# Flatten data
###################################################################
#                    Implementation 3-1                           #
###################################################################
#train_data = None
#test_data = None

###################################################################
#                    Implementation 3-2                           #
###################################################################
x = tf.placeholder(tf.float32, [None, 784])
y_true = tf.placeholder(tf.float32, [None, 10])

###################################################################
#                    Implementation 3-3                          #
###################################################################
h1 = fc('layer1', 512, x)
y_logits = fc('layer2', 10, h1)
y_hat = tf.nn.softmax(y_logits)

###################################################################
#                    Implementation 3-4                           #
###################################################################
cross_entropy = get_cross_entropy_loss(y_true, y_hat)

# Calculate accuracy
accuracy = get_accuracy(y_true, y_hat)
# Make gradient descent op
train_step = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy)

# Make op to initialize declared variable
init = tf.global_variables_initializer()

with tf.Session() as sess:
    # Initialize variables
    sess.run(init)
    
    # Training
    for step in range(max_iter):
        # Get batch data and label
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # train the network and calculate cross entropy
        _, loss = sess.run([train_step, cross_entropy], feed_dict={x: batch_x, y_true: batch_y})
        # calcualte accuracy
        acc = sess.run(accuracy, feed_dict={x: test_data, y_true: test_label})
        # print loss (cross entropy) and accuracy at every 10th step
        if (step + 1) % 10 == 0:
            print("{}th iteration, loss: {:.4f}, test accuracy: {:.4f}".format(step + 1, loss, acc))
# Out:
# 10th iteration, loss: 0.5294, test accuracy: 0.7930
# 20th iteration, loss: 0.5380, test accuracy: 0.8158
# 30th iteration, loss: 0.7953, test accuracy: 0.8496
# 40th iteration, loss: 0.4005, test accuracy: 0.8720
# 50th iteration, loss: 0.5651, test accuracy: 0.8639
# 60th iteration, loss: 0.6430, test accuracy: 0.8709
# 70th iteration, loss: 0.4596, test accuracy: 0.8658
# 80th iteration, loss: 0.7445, test accuracy: 0.8154
# 90th iteration, loss: 0.5466, test accuracy: 0.8560
# 100th iteration, loss: 0.5012, test accuracy: 0.8477
# 110th iteration, loss: 0.6444, test accuracy: 0.8308
# 120th iteration, loss: 0.6276, test accuracy: 0.8484
# 130th iteration, loss: 1.0731, test accuracy: 0.8405
# 140th iteration, loss: 0.4584, test accuracy: 0.8636
# 150th iteration, loss: 0.7703, test accuracy: 0.8546
# 160th iteration, loss: 0.7955, test accuracy: 0.8553
# 170th iteration, loss: 0.4183, test accuracy: 0.8678
# 180th iteration, loss: 0.3566, test accuracy: 0.8580
# 190th iteration, loss: 0.2943, test accuracy: 0.8643
# 200th iteration, loss: 0.8867, test accuracy: 0.8457
# 210th iteration, loss: 0.7311, test accuracy: 0.8245
# 220th iteration, loss: 0.2950, test accuracy: 0.8572
# 230th iteration, loss: 0.5622, test accuracy: 0.8411
# 240th iteration, loss: 0.3516, test accuracy: 0.8642
# 250th iteration, loss: 0.6386, test accuracy: 0.8586
# 260th iteration, loss: 0.5677, test accuracy: 0.8843
# 270th iteration, loss: 0.9160, test accuracy: 0.8607
# 280th iteration, loss: 0.7421, test accuracy: 0.8503
# 290th iteration, loss: 0.4807, test accuracy: 0.8918
# 300th iteration, loss: 0.2585, test accuracy: 0.8613
# 310th iteration, loss: 0.3728, test accuracy: 0.8832
# 320th iteration, loss: 0.4962, test accuracy: 0.8720
# 330th iteration, loss: 0.7576, test accuracy: 0.8526
# 340th iteration, loss: 0.7486, test accuracy: 0.8791
# 350th iteration, loss: 0.5944, test accuracy: 0.8533
# 360th iteration, loss: 0.3447, test accuracy: 0.8667
# 370th iteration, loss: 0.2010, test accuracy: 0.8802
# 380th iteration, loss: 0.4732, test accuracy: 0.8889
# 390th iteration, loss: 0.3782, test accuracy: 0.8696
# 400th iteration, loss: 0.5737, test accuracy: 0.8925
# 410th iteration, loss: 0.2016, test accuracy: 0.8755
# 420th iteration, loss: 0.4465, test accuracy: 0.8621
# 430th iteration, loss: 0.9412, test accuracy: 0.8743
# 440th iteration, loss: 0.4590, test accuracy: 0.8708
# 450th iteration, loss: 0.6208, test accuracy: 0.8664
# 460th iteration, loss: 0.5097, test accuracy: 0.8921
# 470th iteration, loss: 0.8466, test accuracy: 0.8869
# 480th iteration, loss: 0.4093, test accuracy: 0.8726
# 490th iteration, loss: 0.6792, test accuracy: 0.8809
# 500th iteration, loss: 0.7131, test accuracy: 0.8630
# 510th iteration, loss: 0.3963, test accuracy: 0.8808
# 520th iteration, loss: 0.4173, test accuracy: 0.8876
# 530th iteration, loss: 0.5909, test accuracy: 0.8801
# 540th iteration, loss: 0.5826, test accuracy: 0.8691
# 550th iteration, loss: 0.5244, test accuracy: 0.8662
# 560th iteration, loss: 0.6883, test accuracy: 0.8803
# 570th iteration, loss: 1.0710, test accuracy: 0.8473
# 580th iteration, loss: 0.3901, test accuracy: 0.8863
# 590th iteration, loss: 0.4925, test accuracy: 0.8831
# 600th iteration, loss: 0.7717, test accuracy: 0.8673
# 610th iteration, loss: 0.7622, test accuracy: 0.8858
# 620th iteration, loss: 0.4934, test accuracy: 0.8600
# 630th iteration, loss: 0.8653, test accuracy: 0.8686
# 640th iteration, loss: 0.5821, test accuracy: 0.8680
# 650th iteration, loss: 0.4416, test accuracy: 0.8788
# 660th iteration, loss: 0.8435, test accuracy: 0.8631
# 670th iteration, loss: 0.5186, test accuracy: 0.8746
# 680th iteration, loss: 0.3053, test accuracy: 0.8846
# 690th iteration, loss: 0.2664, test accuracy: 0.8920
# 700th iteration, loss: 0.1568, test accuracy: 0.8889
# 710th iteration, loss: 0.2123, test accuracy: 0.8978
# 720th iteration, loss: 0.5664, test accuracy: 0.8898
# 730th iteration, loss: 0.4887, test accuracy: 0.8871
# 740th iteration, loss: 0.2323, test accuracy: 0.8867
# 750th iteration, loss: 0.3667, test accuracy: 0.8769
# 760th iteration, loss: 0.4527, test accuracy: 0.8779
# 770th iteration, loss: 0.7557, test accuracy: 0.8845
# 780th iteration, loss: 0.3486, test accuracy: 0.8761
# 790th iteration, loss: 0.4231, test accuracy: 0.8964
# 800th iteration, loss: 0.7814, test accuracy: 0.8917
# 810th iteration, loss: 0.5913, test accuracy: 0.8955
# 820th iteration, loss: 0.4878, test accuracy: 0.8904
# 830th iteration, loss: 0.2981, test accuracy: 0.8989
# 840th iteration, loss: 0.6985, test accuracy: 0.8609
# 850th iteration, loss: 0.3318, test accuracy: 0.8898
# 860th iteration, loss: 0.2409, test accuracy: 0.8975
# 870th iteration, loss: 0.3637, test accuracy: 0.8904
# 880th iteration, loss: 0.2700, test accuracy: 0.8656
# 890th iteration, loss: 0.3751, test accuracy: 0.8577
# 900th iteration, loss: 0.3956, test accuracy: 0.8768
# 910th iteration, loss: 0.8465, test accuracy: 0.8651
# 920th iteration, loss: 0.3770, test accuracy: 0.8855
# 930th iteration, loss: nan, test accuracy: 0.0980
# 940th iteration, loss: nan, test accuracy: 0.0980
# 950th iteration, loss: nan, test accuracy: 0.0980
# 960th iteration, loss: nan, test accuracy: 0.0980
# 970th iteration, loss: nan, test accuracy: 0.0980
# 980th iteration, loss: nan, test accuracy: 0.0980
# 990th iteration, loss: nan, test accuracy: 0.0980
# 1000th iteration, loss: nan, test accuracy: 0.0980
# 1010th iteration, loss: nan, test accuracy: 0.0980
# 1020th iteration, loss: nan, test accuracy: 0.0980
# 1030th iteration, loss: nan, test accuracy: 0.0980
# 1040th iteration, loss: nan, test accuracy: 0.0980
# 1050th iteration, loss: nan, test accuracy: 0.0980
# 1060th iteration, loss: nan, test accuracy: 0.0980
# 1070th iteration, loss: nan, test accuracy: 0.0980
# 1080th iteration, loss: nan, test accuracy: 0.0980
# 1090th iteration, loss: nan, test accuracy: 0.0980
# 1100th iteration, loss: nan, test accuracy: 0.0980
# 1110th iteration, loss: nan, test accuracy: 0.0980
# 1120th iteration, loss: nan, test accuracy: 0.0980
# 1130th iteration, loss: nan, test accuracy: 0.0980
# 1140th iteration, loss: nan, test accuracy: 0.0980
# 1150th iteration, loss: nan, test accuracy: 0.0980
# 1160th iteration, loss: nan, test accuracy: 0.0980
# 1170th iteration, loss: nan, test accuracy: 0.0980
# 1180th iteration, loss: nan, test accuracy: 0.0980
# 1190th iteration, loss: nan, test accuracy: 0.0980
# 1200th iteration, loss: nan, test accuracy: 0.0980
# 1210th iteration, loss: nan, test accuracy: 0.0980
# 1220th iteration, loss: nan, test accuracy: 0.0980
# 1230th iteration, loss: nan, test accuracy: 0.0980
# 1240th iteration, loss: nan, test accuracy: 0.0980
# 1250th iteration, loss: nan, test accuracy: 0.0980
# 1260th iteration, loss: nan, test accuracy: 0.0980
# 1270th iteration, loss: nan, test accuracy: 0.0980
# 1280th iteration, loss: nan, test accuracy: 0.0980
# 1290th iteration, loss: nan, test accuracy: 0.0980
# 1300th iteration, loss: nan, test accuracy: 0.0980
# 1310th iteration, loss: nan, test accuracy: 0.0980
# 1320th iteration, loss: nan, test accuracy: 0.0980
# 1330th iteration, loss: nan, test accuracy: 0.0980
# 1340th iteration, loss: nan, test accuracy: 0.0980
# 1350th iteration, loss: nan, test accuracy: 0.0980
# 1360th iteration, loss: nan, test accuracy: 0.0980
# 1370th iteration, loss: nan, test accuracy: 0.0980
# 1380th iteration, loss: nan, test accuracy: 0.0980
# 1390th iteration, loss: nan, test accuracy: 0.0980
# 1400th iteration, loss: nan, test accuracy: 0.0980
# 1410th iteration, loss: nan, test accuracy: 0.0980
# 1420th iteration, loss: nan, test accuracy: 0.0980
# 1430th iteration, loss: nan, test accuracy: 0.0980
# 1440th iteration, loss: nan, test accuracy: 0.0980
# 1450th iteration, loss: nan, test accuracy: 0.0980
# 1460th iteration, loss: nan, test accuracy: 0.0980
# 1470th iteration, loss: nan, test accuracy: 0.0980
# 1480th iteration, loss: nan, test accuracy: 0.0980
# 1490th iteration, loss: nan, test accuracy: 0.0980
# 1500th iteration, loss: nan, test accuracy: 0.0980
# 1510th iteration, loss: nan, test accuracy: 0.0980
# 1520th iteration, loss: nan, test accuracy: 0.0980
# 1530th iteration, loss: nan, test accuracy: 0.0980
# 1540th iteration, loss: nan, test accuracy: 0.0980
# 1550th iteration, loss: nan, test accuracy: 0.0980
# 1560th iteration, loss: nan, test accuracy: 0.0980
# 1570th iteration, loss: nan, test accuracy: 0.0980
# 1580th iteration, loss: nan, test accuracy: 0.0980
# 1590th iteration, loss: nan, test accuracy: 0.0980
# 1600th iteration, loss: nan, test accuracy: 0.0980
# 1610th iteration, loss: nan, test accuracy: 0.0980
# 1620th iteration, loss: nan, test accuracy: 0.0980
# 1630th iteration, loss: nan, test accuracy: 0.0980
# 1640th iteration, loss: nan, test accuracy: 0.0980
# 1650th iteration, loss: nan, test accuracy: 0.0980
# 1660th iteration, loss: nan, test accuracy: 0.0980
# 1670th iteration, loss: nan, test accuracy: 0.0980
# 1680th iteration, loss: nan, test accuracy: 0.0980
# 1690th iteration, loss: nan, test accuracy: 0.0980
# 1700th iteration, loss: nan, test accuracy: 0.0980
# 1710th iteration, loss: nan, test accuracy: 0.0980
# 1720th iteration, loss: nan, test accuracy: 0.0980
# 1730th iteration, loss: nan, test accuracy: 0.0980
# 1740th iteration, loss: nan, test accuracy: 0.0980
# 1750th iteration, loss: nan, test accuracy: 0.0980
# 1760th iteration, loss: nan, test accuracy: 0.0980
# 1770th iteration, loss: nan, test accuracy: 0.0980
# 1780th iteration, loss: nan, test accuracy: 0.0980
# 1790th iteration, loss: nan, test accuracy: 0.0980
# 1800th iteration, loss: nan, test accuracy: 0.0980
# 1810th iteration, loss: nan, test accuracy: 0.0980
# 1820th iteration, loss: nan, test accuracy: 0.0980
# 1830th iteration, loss: nan, test accuracy: 0.0980
# 1840th iteration, loss: nan, test accuracy: 0.0980
# 1850th iteration, loss: nan, test accuracy: 0.0980
# 1860th iteration, loss: nan, test accuracy: 0.0980
# 1870th iteration, loss: nan, test accuracy: 0.0980
# 1880th iteration, loss: nan, test accuracy: 0.0980
# 1890th iteration, loss: nan, test accuracy: 0.0980
# 1900th iteration, loss: nan, test accuracy: 0.0980
# 1910th iteration, loss: nan, test accuracy: 0.0980
# 1920th iteration, loss: nan, test accuracy: 0.0980
# 1930th iteration, loss: nan, test accuracy: 0.0980
# 1940th iteration, loss: nan, test accuracy: 0.0980
# 1950th iteration, loss: nan, test accuracy: 0.0980
# 1960th iteration, loss: nan, test accuracy: 0.0980
# 1970th iteration, loss: nan, test accuracy: 0.0980
# 1980th iteration, loss: nan, test accuracy: 0.0980
# 1990th iteration, loss: nan, test accuracy: 0.0980
# 2000th iteration, loss: nan, test accuracy: 0.0980
