# %% [markdown]
# #pip install pillow==5.1.0 (pillow 반드시 소문자!!!)

# %% [markdown]
# ### Simple CNN Image Classification
# 이번 실습에서는 tensorflow library를 이용하여 간단한 CNN 구조를 생성하고 CIFAR-10 dataset을 학습하여 성능을 평가한다.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# pylint: disable=missing-docstring
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import sys
import math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (10,10)

sys.path.append(os.path.join(os.getcwd(), '..'))
from cifar10_loader import CIFAR10_loader
from utils import *

# %% [markdown]
# ### Download the CIFAR-10 dataset
# **CIFAR-10** dataset은 32x32 사이즈의 이미지들로 airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck으로 이루어져있다. 각 클래스 별 6천장씩 구성되어 있으며 이중 50000장이 training에 사용되고 10000장이 test에 사용된다. TF-Slim library에서 제공하는 코드를 이용하여 현재 작업중인 폴더의 하위 폴더에 cifar-10 dataset을 저장한다.
#
# *CIFAR datasets URL*: https://www.cs.toronto.edu/~kriz/cifar.html
#
# *CIFAR-10 download link*: https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz

# %%
data_dir = 'cifar10_data'
data_url = 'http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz'
maybe_download_and_extract(data_url, data_dir, 'cifar-10-batches')
# Out:
# Extracting Finished

# %% [markdown]
# ### Create data loader and check the CIFAR-10 dataset
# 위에서 다운받은 데이터를 batch 단위로 읽어올 수 있는 data loader class를 선언. 현재 data loader는 get_batch()를 통해 단순히 이미지 및 레이블을 batch 크기만큼 받아올 수 있으며, 여기서는 특별한 preprocessing을 하지는 않는다. 하지만 보통 더 높은 성능을 위해서 random crop, flipping 등의 preprocessing을 하는 편이다.

# %%
loader = CIFAR10_loader()
class_names = loader.get_class_names()

# %%
batch = loader.get_batch(9)
fig = plot_images(batch['images'], batch['labels'], class_names)
fig.show()
# Out:
# /home/pirl/anaconda2/envs/vision/lib/python3.6/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# ### Functions for constructing model (graph)
# Object classification을 위한 convolutional 네트워크를 선언하자. 네트워크를 선언하는 코딩 스타일은 사람마다 다르나 보통 아래와 같이 5부분 (input, model, loss, optimizer, accuracy)으로 나눠서 선언하는 경우가 많다.
#  - build_model(): 네트워크의 실제 연산을 담당하는 부분으로 2개의 convolutional layer 및 2개의 fully connected layer와 classification layer로 구성된다.
#  - build_loss(): 학습을 위한 loss를 정의하며 여기에서는 cross-entropy loss를 사용한다.
#  - build_train_operation(): 학습을 위한 파라미터들의 gradient 계산 및 파라미터 업데이트를 하는 optimizer를 정의. 여기에서는 Adam optimizer를 사용한다.
#  - build_accuracy(): 테스트를 위하여 accuracry를 정의.
#
#  tensorflow python api page: https://www.tensorflow.org/api_docs/

# %% [markdown]
# ### Tensorflow Initializer
# - tf.constant_initializer()
# - tf.truncated_normal_initializer()
# - tf.random.uniform_initializer()
#
# tf.contrib.layers.xavier_initializer(uniform=True, seed=None, dtype=tf.float32)
# - range W = [-sqrt(6 / (in + out), sqrt(6 / (in + out)] (for uniform)
# - range W = [-sqrt(3 / (in + out), sqrt(3 / (in + out)] (for normal)

# %% [markdown]
# #### Practice
# xavier initializer로 바꿔서 weight을 초기화 하시오.

# %%
loader.reset() # set iterator as 0

# Get variable initialization function
initializer = tf.truncated_normal_initializer(stddev=0.01, dtype=tf.float32)

# %%
def build_inputs(batch_size, image_size):
    """ Construct input for CIFAR evaluation using the Reader ops.
    Args:
        batch_size: Batch size.
        image_size: Image size.
    Returns:
        images: Images. 4D tensor of [batch_size, IMAGE_SIZE, IMAGE_SIZE, 3] size.
        labels: Labels. 1D tensor of [batch_size] size.
    """
    with tf.variable_scope('inputs') as scope:
        images = tf.placeholder(dtype=tf.float32, shape=[batch_size, image_size, image_size, 3],
                               name='images')
        labels = tf.placeholder(dtype=tf.int64, shape=[batch_size], name='labels')
    
    return images, labels

# %% [markdown]
# ### Tensorflow layers
# https://www.tensorflow.org/api_guides/python/contrib.layers
#
# - tf.contrib.layers.conv2d()
# - tf.contrib.layers.max_pool2d
# - tf.contrib.layers.flatten()
# - tf.contrib.layers.fully_connected()
# - tf.contrib.layers.dropout()

# %% [markdown]
# #### Practice
# CNN 구조를 ppt에 나온 구조로 바꿔서 학습하시오.
#
# - conv3x3 32
# - conv3x3 32
# - maxpool
# - conv3x3 64
# - conv3x3 64
# - maxpool
# - FC-512
# - FC-512

# %%
def build_model(images):
    """ Build the CIFAR-10 model consists of 2 convolutional, 2 fully connected and
    1 classification layer.
    Args:
        images: Images returned from build_inputs(). 4-D tensor.
    Returns:
        Logits.
    """
    
    # conv1
    conv1     = tf.contrib.layers.conv2d(images, 64, [3, 3], padding='SAME', activation_fn=tf.nn.relu, weights_initializer=initializer, scope='conv1')
    # pool1
    max_pool1 = tf.contrib.layers.max_pool2d(conv1, [2, 2], padding='VALID', scope='pool1')
    # conv2
    conv2     = tf.contrib.layers.conv2d(max_pool1, 64, [3, 3], padding='SAME', 
                                         activation_fn=tf.nn.relu, weights_initializer=initializer, scope='conv2')
    # pool2
    max_pool2 = tf.contrib.layers.max_pool2d(conv2, [2, 2], padding='VALID', scope='pool2')
    
    flat = tf.contrib.layers.flatten(max_pool2)
    
    # fc1
    fc1 = tf.contrib.layers.fully_connected(flat, 384, activation_fn=tf.nn.relu, weights_initializer=initializer, scope='fc1')
    fc1_dropout = tf.contrib.layers.dropout(fc1, 0.5, is_training=True, scope='dropout1')
    # fc2
    fc2 = tf.contrib.layers.fully_connected(fc1_dropout, 192, activation_fn=tf.nn.relu, weights_initializer=initializer, scope='fc2')
    fc2_dropout = tf.contrib.layers.dropout(fc2, 0.5, is_training=True, scope='dropout2')
    # fc3
    logits = tf.contrib.layers.fully_connected(fc2_dropout, loader.get_num_classes(), activation_fn=None, normalizer_fn=None, scope='fc3')
        
    return logits

# %% [markdown]
# ### Tensorflow losses
# https://www.tensorflow.org/api_docs/python/tf/nn
#
# cross entropy loss with softmax is best

# %%
def build_loss(logits, labels):
    """ Add L2Loss to all the trainable variables.
    Add summary for "Loss" and "Loss/avg".
    Args:
        logits: Logits from build_model().
        labels: Labels from build_inputs(). 1-D tensor.
    Returns:
        Loss tensor of type float.
    """
    # Calculate the average cross entropy loss across the batch.
    labels = tf.cast(labels, tf.int64)
    cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(
            labels=labels, logits=logits, name='cross_entropy_per_example')
    cross_entropy_mean = tf.reduce_mean(cross_entropy, name='cross_entropy')
    #tf.add_to_collection('losses', cross_entropy_mean)

    # The total loss is defined as the cross entropy loss plus all 
    # of the weight decay terms (L2 loss).
    #return tf.add_n(tf.get_collection('losses'), name='total_loss')
    return cross_entropy_mean

# %% [markdown]
# ### Tensorflow traning
# Gradient optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers
#
# - tf.train.GradientDescentOptimizer()
# - tf.train.AdamOptimizer()
# - tf.train.MomentumOptimizer()

# %%
def build_train_operation(total_loss):
    """ Train CIFAR-10 model and create an optimizer.
    Args:
        total_loss: Total loss from build_loss().
        
    Returns:
        train_op: op for training.
        global_step: global step counting iteration
    """
    global_step = tf.Variable(initial_value=0, name='global_step', trainable=False)
    #learning_rate = 0.0001
    
    lr = tf.train.exponential_decay(
    learning_rate = 0.001,
    global_step = global_step,
    decay_steps = 10000,
    decay_rate = 0.9,
    staircase = True)
    
    # Create the optimizer which will minimize the loss.
    # Below two methods are equivalent. But, when you want to process
    # the gradients before updating a model, second method is appropriate.
    #train_op = tf.train.AdamOptimizer(learning_rate).minimize(total_loss, global_step=global_step)
    train_op = tf.train.AdamOptimizer(learning_rate=lr).minimize(total_loss, global_step=global_step)
    return train_op, global_step

def build_accuracy(logits, labels):
    """ Accuarcy computed by
        accuracy = # of correct examples / # of total examples
    Args:
        logits: Logits from build_model().
        labels: Labels from build_model().
    Returns:
        accuracy: Accuracy.
        correct_num: The number of corrected examples
        pred_labels: Predicted labels by the model
    """
    pred_labels = tf.argmax(logits, axis=1)
    correct_prediction = tf.equal(pred_labels, tf.cast(labels, tf.int64))
    correct_num = tf.reduce_sum(tf.cast(correct_prediction, tf.float32))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    return accuracy, correct_num, pred_labels

# %% [markdown]
# ### Training the model

# %% [markdown]
# 모델 학습을 위한 파라미터 정의

# %%
# Model parameters
batch_size = 100
num_epochs = 50
iteration_per_epoch = int(math.floor(loader.get_num_train_examples() / batch_size))
save_checkpoint_frequency = 500
print_frequency = 100

# %% [markdown]
# 모델 정의

# %%
"""Train CIFAR-10 for a number of steps."""
tf.reset_default_graph()

# build input placeholders
images, labels = build_inputs(batch_size, loader.get_image_size())

# Build a Graph that computes the logits predictions from the
# inference model.
logits = build_model(images)

# Calculate loss.
loss = build_loss(logits, labels)

# Build a Graph that trains the model with one batch of examples and
# updates the model parameters.
train_op, global_step = build_train_operation(loss)

# Build the accuracy and correct number of examples
# to check model is learned correctly while training
accuracy, correct_num, prediction = build_accuracy(logits, labels)

# %% [markdown]
# 모델을 실행 할 session을 생성 및 모델의 weight를 초기화

# %%
# Open the session
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %% [markdown]
# 정의한 모델을 구성하는 layer 및 그 name을 확인하는 방법을 알아보자. 또한, 특정 variable을 얻고 그 값을 확인하는 방법을 알아보자.

# %%
print('The list of variables (or layers) in the model:')
for var in tf.global_variables():
    print(var)
    #print(var.op.name)
# Out:
# The list of variables (or layers) in the model:
# <tf.Variable 'conv1/weights:0' shape=(3, 3, 3, 64) dtype=float32_ref>
# <tf.Variable 'conv1/biases:0' shape=(64,) dtype=float32_ref>
# <tf.Variable 'conv2/weights:0' shape=(3, 3, 64, 64) dtype=float32_ref>
# <tf.Variable 'conv2/biases:0' shape=(64,) dtype=float32_ref>
# <tf.Variable 'fc1/weights:0' shape=(4096, 384) dtype=float32_ref>
# <tf.Variable 'fc1/biases:0' shape=(384,) dtype=float32_ref>
# <tf.Variable 'fc2/weights:0' shape=(384, 192) dtype=float32_ref>
# <tf.Variable 'fc2/biases:0' shape=(192,) dtype=float32_ref>
# <tf.Variable 'fc3/weights:0' shape=(192, 10) dtype=float32_ref>
# <tf.Variable 'fc3/biases:0' shape=(10,) dtype=float32_ref>
# <tf.Variable 'global_step:0' shape=() dtype=int32_ref>
# <tf.Variable 'beta1_power:0' shape=() dtype=float32_ref>
# <tf.Variable 'beta2_power:0' shape=() dtype=float32_ref>
# <tf.Variable 'conv1/weights/Adam:0' shape=(3, 3, 3, 64) dtype=float32_ref>
# <tf.Variable 'conv1/weights/Adam_1:0' shape=(3, 3, 3, 64) dtype=float32_ref>
# <tf.Variable 'conv1/biases/Adam:0' shape=(64,) dtype=float32_ref>
# <tf.Variable 'conv1/biases/Adam_1:0' shape=(64,) dtype=float32_ref>
# <tf.Variable 'conv2/weights/Adam:0' shape=(3, 3, 64, 64) dtype=float32_ref>
# <tf.Variable 'conv2/weights/Adam_1:0' shape=(3, 3, 64, 64) dtype=float32_ref>
# <tf.Variable 'conv2/biases/Adam:0' shape=(64,) dtype=float32_ref>
# <tf.Variable 'conv2/biases/Adam_1:0' shape=(64,) dtype=float32_ref>
# <tf.Variable 'fc1/weights/Adam:0' shape=(4096, 384) dtype=float32_ref>
# <tf.Variable 'fc1/weights/Adam_1:0' shape=(4096, 384) dtype=float32_ref>
# <tf.Variable 'fc1/biases/Adam:0' shape=(384,) dtype=float32_ref>
# <tf.Variable 'fc1/biases/Adam_1:0' shape=(384,) dtype=float32_ref>
# <tf.Variable 'fc2/weights/Adam:0' shape=(384, 192) dtype=float32_ref>
# <tf.Variable 'fc2/weights/Adam_1:0' shape=(384, 192) dtype=float32_ref>
# <tf.Variable 'fc2/biases/Adam:0' shape=(192,) dtype=float32_ref>
# <tf.Variable 'fc2/biases/Adam_1:0' shape=(192,) dtype=float32_ref>
# <tf.Variable 'fc3/weights/Adam:0' shape=(192, 10) dtype=float32_ref>
# <tf.Variable 'fc3/weights/Adam_1:0' shape=(192, 10) dtype=float32_ref>
# <tf.Variable 'fc3/biases/Adam:0' shape=(10,) dtype=float32_ref>
# <tf.Variable 'fc3/biases/Adam_1:0' shape=(10,) dtype=float32_ref>

# %% [markdown]
# 중간 레이어 결과값 혹은 사이즈 확인

# %%
cc = sess.run('conv1/weights:0', feed_dict={images:loader.get_batch(batch_size, 'train')['images']})
print(cc.shape)
# Out:
# (3, 3, 3, 64)

# %%
cc = sess.run('fc1/weights:0', feed_dict={images:loader.get_batch(batch_size, 'train')['images']})
print(cc.shape)
# Out:
# (4096, 384)

# %% [markdown]
# 모델의 파라미터 확인

# %%
logit_weight = tf.get_default_graph().get_tensor_by_name('fc3/weights:0')
logit = logit_weight.eval(session=sess)
print(logit.shape)
print(logit[0,:10])
print(sess.run(logit_weight)[0,:10])
# Out:
# (192, 10)
# [-0.07821873  0.01849388  0.15987761  0.1434872   0.06474815 -0.0815567
#   0.03403701  0.04573888  0.09903108  0.13946925]
# [-0.07821873  0.01849388  0.15987761  0.1434872   0.06474815 -0.0815567
#   0.03403701  0.04573888  0.09903108  0.13946925]

# %% [markdown]
# 모델 학습

# %%
## Model parameters
save_path = 'cifar10_ramdom-init_checkpoints/cifar10_cnn'
if not os.path.exists('cifar10_ramdom-init_checkpoints'): 
    os.makedirs('cifar10_ramdom-init_checkpoints')
    
# Train the model
saver = tf.train.Saver()

# Train the model
for ie in range(num_epochs):
    for ii in range(iteration_per_epoch):
        # Load a batch data
        batch = loader.get_batch(batch_size, 'train')

        # Run the optimizer
        iteration, _ = sess.run([global_step, train_op], 
                                             feed_dict={images:batch['images'],
                                                        labels:batch['labels']})

        # Print the accuracy and loss of current batch data
        if iteration % print_frequency == 0:
            batch_loss, batch_acc = sess.run([loss, accuracy], 
                                             feed_dict={images:batch['images'],
                                                        labels:batch['labels']})
            print('%d Epoch %d iteration - Loss (%.3f) Accuracy (%.3f)' 
                      %(ie+1, ii+1, batch_loss, batch_acc))
            
        # Save checkpoint
        if (ii+1) % save_checkpoint_frequency == 0:
            saver.save(sess, save_path=save_path, global_step=ie*iteration_per_epoch + ii + 1)
            print('Saved checkpoint %s_%d' % (save_path, ie*iteration_per_epoch + ii + 1))

sess.close()
# Out:
# 1 Epoch 100 iteration - Loss (2.145) Accuracy (0.250)
# 1 Epoch 200 iteration - Loss (1.849) Accuracy (0.280)
# 1 Epoch 300 iteration - Loss (1.719) Accuracy (0.300)
# 1 Epoch 400 iteration - Loss (1.770) Accuracy (0.330)
# 1 Epoch 500 iteration - Loss (1.514) Accuracy (0.430)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_500
# 2 Epoch 100 iteration - Loss (1.752) Accuracy (0.440)
# 2 Epoch 200 iteration - Loss (1.444) Accuracy (0.550)
# 2 Epoch 300 iteration - Loss (1.526) Accuracy (0.390)
# 2 Epoch 400 iteration - Loss (1.445) Accuracy (0.460)
# 2 Epoch 500 iteration - Loss (1.258) Accuracy (0.580)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_1000
# 3 Epoch 100 iteration - Loss (1.574) Accuracy (0.530)
# 3 Epoch 200 iteration - Loss (1.415) Accuracy (0.470)
# 3 Epoch 300 iteration - Loss (1.338) Accuracy (0.490)
# 3 Epoch 400 iteration - Loss (1.342) Accuracy (0.510)
# 3 Epoch 500 iteration - Loss (1.155) Accuracy (0.590)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_1500
# 4 Epoch 100 iteration - Loss (1.340) Accuracy (0.550)
# 4 Epoch 200 iteration - Loss (1.152) Accuracy (0.580)
# 4 Epoch 300 iteration - Loss (1.247) Accuracy (0.520)
# 4 Epoch 400 iteration - Loss (1.175) Accuracy (0.550)
# 4 Epoch 500 iteration - Loss (1.042) Accuracy (0.660)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_2000
# 5 Epoch 100 iteration - Loss (1.184) Accuracy (0.610)
# 5 Epoch 200 iteration - Loss (1.244) Accuracy (0.530)
# 5 Epoch 300 iteration - Loss (1.077) Accuracy (0.600)
# 5 Epoch 400 iteration - Loss (1.161) Accuracy (0.620)
# 5 Epoch 500 iteration - Loss (1.071) Accuracy (0.590)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_2500
# 6 Epoch 100 iteration - Loss (1.145) Accuracy (0.630)
# 6 Epoch 200 iteration - Loss (1.110) Accuracy (0.620)
# 6 Epoch 300 iteration - Loss (1.097) Accuracy (0.640)
# 6 Epoch 400 iteration - Loss (1.018) Accuracy (0.650)
# 6 Epoch 500 iteration - Loss (1.011) Accuracy (0.680)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_3000
# 7 Epoch 100 iteration - Loss (1.012) Accuracy (0.680)
# 7 Epoch 200 iteration - Loss (0.942) Accuracy (0.650)
# 7 Epoch 300 iteration - Loss (1.095) Accuracy (0.610)
# 7 Epoch 400 iteration - Loss (0.798) Accuracy (0.670)
# 7 Epoch 500 iteration - Loss (0.841) Accuracy (0.690)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_3500
# 8 Epoch 100 iteration - Loss (1.015) Accuracy (0.660)
# 8 Epoch 200 iteration - Loss (1.016) Accuracy (0.600)
# 8 Epoch 300 iteration - Loss (1.163) Accuracy (0.520)
# 8 Epoch 400 iteration - Loss (0.942) Accuracy (0.660)
# 8 Epoch 500 iteration - Loss (0.871) Accuracy (0.710)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_4000
# 9 Epoch 100 iteration - Loss (0.898) Accuracy (0.680)
# 9 Epoch 200 iteration - Loss (0.835) Accuracy (0.700)
# 9 Epoch 300 iteration - Loss (1.005) Accuracy (0.660)
# 9 Epoch 400 iteration - Loss (0.886) Accuracy (0.690)
# 9 Epoch 500 iteration - Loss (0.817) Accuracy (0.690)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_4500
# 10 Epoch 100 iteration - Loss (0.852) Accuracy (0.690)
# 10 Epoch 200 iteration - Loss (0.837) Accuracy (0.720)
# 10 Epoch 300 iteration - Loss (0.974) Accuracy (0.660)
# 10 Epoch 400 iteration - Loss (0.845) Accuracy (0.750)
# 10 Epoch 500 iteration - Loss (0.711) Accuracy (0.750)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_5000
# 11 Epoch 100 iteration - Loss (0.840) Accuracy (0.670)
# 11 Epoch 200 iteration - Loss (0.822) Accuracy (0.720)
# 11 Epoch 300 iteration - Loss (0.960) Accuracy (0.680)
# 11 Epoch 400 iteration - Loss (0.711) Accuracy (0.740)
# 11 Epoch 500 iteration - Loss (0.755) Accuracy (0.730)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_5500
# 12 Epoch 100 iteration - Loss (0.780) Accuracy (0.710)
# 12 Epoch 200 iteration - Loss (0.855) Accuracy (0.710)
# 12 Epoch 300 iteration - Loss (0.896) Accuracy (0.660)
# 12 Epoch 400 iteration - Loss (0.862) Accuracy (0.680)
# 12 Epoch 500 iteration - Loss (0.770) Accuracy (0.720)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_6000
# 13 Epoch 100 iteration - Loss (0.816) Accuracy (0.670)
# 13 Epoch 200 iteration - Loss (0.902) Accuracy (0.660)
# 13 Epoch 300 iteration - Loss (0.938) Accuracy (0.680)
# 13 Epoch 400 iteration - Loss (0.832) Accuracy (0.770)
# 13 Epoch 500 iteration - Loss (0.620) Accuracy (0.770)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_6500
# 14 Epoch 100 iteration - Loss (0.750) Accuracy (0.730)
# 14 Epoch 200 iteration - Loss (0.782) Accuracy (0.710)
# 14 Epoch 300 iteration - Loss (0.872) Accuracy (0.720)
# 14 Epoch 400 iteration - Loss (0.755) Accuracy (0.750)
# 14 Epoch 500 iteration - Loss (0.684) Accuracy (0.770)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_7000
# 15 Epoch 100 iteration - Loss (0.643) Accuracy (0.800)
# 15 Epoch 200 iteration - Loss (0.772) Accuracy (0.710)
# 15 Epoch 300 iteration - Loss (0.757) Accuracy (0.710)
# 15 Epoch 400 iteration - Loss (0.688) Accuracy (0.810)
# 15 Epoch 500 iteration - Loss (0.694) Accuracy (0.750)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_7500
# 16 Epoch 100 iteration - Loss (0.645) Accuracy (0.770)
# 16 Epoch 200 iteration - Loss (0.806) Accuracy (0.720)
# 16 Epoch 300 iteration - Loss (0.881) Accuracy (0.690)
# 16 Epoch 400 iteration - Loss (0.732) Accuracy (0.720)
# 16 Epoch 500 iteration - Loss (0.602) Accuracy (0.770)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_8000
# 17 Epoch 100 iteration - Loss (0.536) Accuracy (0.810)
# 17 Epoch 200 iteration - Loss (0.646) Accuracy (0.750)
# 17 Epoch 300 iteration - Loss (0.703) Accuracy (0.770)
# 17 Epoch 400 iteration - Loss (0.661) Accuracy (0.740)
# 17 Epoch 500 iteration - Loss (0.544) Accuracy (0.780)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_8500
# 18 Epoch 100 iteration - Loss (0.463) Accuracy (0.820)
# 18 Epoch 200 iteration - Loss (0.626) Accuracy (0.770)
# 18 Epoch 300 iteration - Loss (0.738) Accuracy (0.700)
# 18 Epoch 400 iteration - Loss (0.689) Accuracy (0.780)
# 18 Epoch 500 iteration - Loss (0.551) Accuracy (0.810)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_9000
# 19 Epoch 100 iteration - Loss (0.519) Accuracy (0.810)
# 19 Epoch 200 iteration - Loss (0.601) Accuracy (0.760)
# 19 Epoch 300 iteration - Loss (0.637) Accuracy (0.730)
# 19 Epoch 400 iteration - Loss (0.622) Accuracy (0.780)
# 19 Epoch 500 iteration - Loss (0.647) Accuracy (0.780)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_9500
# 20 Epoch 100 iteration - Loss (0.515) Accuracy (0.830)
# 20 Epoch 200 iteration - Loss (0.569) Accuracy (0.780)
# 20 Epoch 300 iteration - Loss (0.724) Accuracy (0.790)
# 20 Epoch 400 iteration - Loss (0.687) Accuracy (0.730)
# 20 Epoch 500 iteration - Loss (0.507) Accuracy (0.780)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_10000
# 21 Epoch 100 iteration - Loss (0.459) Accuracy (0.800)
# 21 Epoch 200 iteration - Loss (0.618) Accuracy (0.790)
# 21 Epoch 300 iteration - Loss (0.681) Accuracy (0.780)
# 21 Epoch 400 iteration - Loss (0.547) Accuracy (0.770)
# 21 Epoch 500 iteration - Loss (0.529) Accuracy (0.850)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_10500
# 22 Epoch 100 iteration - Loss (0.505) Accuracy (0.830)
# 22 Epoch 200 iteration - Loss (0.608) Accuracy (0.790)
# 22 Epoch 300 iteration - Loss (0.610) Accuracy (0.800)
# 22 Epoch 400 iteration - Loss (0.651) Accuracy (0.710)
# 22 Epoch 500 iteration - Loss (0.539) Accuracy (0.830)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_11000
# 23 Epoch 100 iteration - Loss (0.452) Accuracy (0.840)
# 23 Epoch 200 iteration - Loss (0.571) Accuracy (0.800)
# 23 Epoch 300 iteration - Loss (0.648) Accuracy (0.750)
# 23 Epoch 400 iteration - Loss (0.541) Accuracy (0.780)
# 23 Epoch 500 iteration - Loss (0.470) Accuracy (0.830)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_11500
# 24 Epoch 100 iteration - Loss (0.467) Accuracy (0.800)
# 24 Epoch 200 iteration - Loss (0.642) Accuracy (0.790)
# 24 Epoch 300 iteration - Loss (0.631) Accuracy (0.750)
# 24 Epoch 400 iteration - Loss (0.565) Accuracy (0.830)
# 24 Epoch 500 iteration - Loss (0.434) Accuracy (0.860)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_12000
# 25 Epoch 100 iteration - Loss (0.476) Accuracy (0.860)
# 25 Epoch 200 iteration - Loss (0.573) Accuracy (0.800)
# 25 Epoch 300 iteration - Loss (0.656) Accuracy (0.780)
# 25 Epoch 400 iteration - Loss (0.457) Accuracy (0.800)
# 25 Epoch 500 iteration - Loss (0.460) Accuracy (0.850)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_12500
# 26 Epoch 100 iteration - Loss (0.448) Accuracy (0.860)
# 26 Epoch 200 iteration - Loss (0.480) Accuracy (0.830)
# 26 Epoch 300 iteration - Loss (0.537) Accuracy (0.810)
# 26 Epoch 400 iteration - Loss (0.533) Accuracy (0.830)
# 26 Epoch 500 iteration - Loss (0.471) Accuracy (0.800)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_13000
# 27 Epoch 100 iteration - Loss (0.370) Accuracy (0.860)
# 27 Epoch 200 iteration - Loss (0.518) Accuracy (0.800)
# 27 Epoch 300 iteration - Loss (0.709) Accuracy (0.780)
# 27 Epoch 400 iteration - Loss (0.358) Accuracy (0.860)
# 27 Epoch 500 iteration - Loss (0.439) Accuracy (0.840)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_13500
# 28 Epoch 100 iteration - Loss (0.452) Accuracy (0.860)
# 28 Epoch 200 iteration - Loss (0.549) Accuracy (0.810)
# 28 Epoch 300 iteration - Loss (0.484) Accuracy (0.800)
# 28 Epoch 400 iteration - Loss (0.424) Accuracy (0.830)
# 28 Epoch 500 iteration - Loss (0.511) Accuracy (0.820)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_14000
# 29 Epoch 100 iteration - Loss (0.436) Accuracy (0.860)
# 29 Epoch 200 iteration - Loss (0.601) Accuracy (0.770)
# 29 Epoch 300 iteration - Loss (0.430) Accuracy (0.830)
# 29 Epoch 400 iteration - Loss (0.467) Accuracy (0.820)
# 29 Epoch 500 iteration - Loss (0.450) Accuracy (0.840)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_14500
# 30 Epoch 100 iteration - Loss (0.355) Accuracy (0.880)
# 30 Epoch 200 iteration - Loss (0.538) Accuracy (0.830)
# 30 Epoch 300 iteration - Loss (0.468) Accuracy (0.840)
# 30 Epoch 400 iteration - Loss (0.432) Accuracy (0.820)
# 30 Epoch 500 iteration - Loss (0.466) Accuracy (0.820)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_15000
# 31 Epoch 100 iteration - Loss (0.382) Accuracy (0.840)
# 31 Epoch 200 iteration - Loss (0.498) Accuracy (0.780)
# 31 Epoch 300 iteration - Loss (0.557) Accuracy (0.750)
# 31 Epoch 400 iteration - Loss (0.512) Accuracy (0.820)
# 31 Epoch 500 iteration - Loss (0.468) Accuracy (0.880)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_15500
# 32 Epoch 100 iteration - Loss (0.409) Accuracy (0.850)
# 32 Epoch 200 iteration - Loss (0.446) Accuracy (0.860)
# 32 Epoch 300 iteration - Loss (0.509) Accuracy (0.780)
# 32 Epoch 400 iteration - Loss (0.498) Accuracy (0.790)
# 32 Epoch 500 iteration - Loss (0.469) Accuracy (0.790)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_16000
# 33 Epoch 100 iteration - Loss (0.329) Accuracy (0.870)
# 33 Epoch 200 iteration - Loss (0.402) Accuracy (0.850)
# 33 Epoch 300 iteration - Loss (0.524) Accuracy (0.780)
# 33 Epoch 400 iteration - Loss (0.591) Accuracy (0.790)
# 33 Epoch 500 iteration - Loss (0.468) Accuracy (0.840)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_16500
# 34 Epoch 100 iteration - Loss (0.548) Accuracy (0.790)
# 34 Epoch 200 iteration - Loss (0.369) Accuracy (0.870)
# 34 Epoch 300 iteration - Loss (0.710) Accuracy (0.770)
# 34 Epoch 400 iteration - Loss (0.326) Accuracy (0.890)
# 34 Epoch 500 iteration - Loss (0.378) Accuracy (0.870)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_17000
# 35 Epoch 100 iteration - Loss (0.317) Accuracy (0.870)
# 35 Epoch 200 iteration - Loss (0.419) Accuracy (0.820)
# 35 Epoch 300 iteration - Loss (0.500) Accuracy (0.780)
# 35 Epoch 400 iteration - Loss (0.327) Accuracy (0.880)
# 35 Epoch 500 iteration - Loss (0.306) Accuracy (0.910)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_17500
# 36 Epoch 100 iteration - Loss (0.341) Accuracy (0.850)
# 36 Epoch 200 iteration - Loss (0.309) Accuracy (0.870)
# 36 Epoch 300 iteration - Loss (0.386) Accuracy (0.870)
# 36 Epoch 400 iteration - Loss (0.556) Accuracy (0.800)
# 36 Epoch 500 iteration - Loss (0.417) Accuracy (0.840)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_18000
# 37 Epoch 100 iteration - Loss (0.504) Accuracy (0.820)
# 37 Epoch 200 iteration - Loss (0.420) Accuracy (0.810)
# 37 Epoch 300 iteration - Loss (0.581) Accuracy (0.780)
# 37 Epoch 400 iteration - Loss (0.386) Accuracy (0.870)
# 37 Epoch 500 iteration - Loss (0.388) Accuracy (0.860)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_18500
# 38 Epoch 100 iteration - Loss (0.313) Accuracy (0.850)
# 38 Epoch 200 iteration - Loss (0.376) Accuracy (0.870)
# 38 Epoch 300 iteration - Loss (0.536) Accuracy (0.820)
# 38 Epoch 400 iteration - Loss (0.460) Accuracy (0.830)
# 38 Epoch 500 iteration - Loss (0.444) Accuracy (0.820)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_19000
# 39 Epoch 100 iteration - Loss (0.387) Accuracy (0.850)
# 39 Epoch 200 iteration - Loss (0.390) Accuracy (0.840)
# 39 Epoch 300 iteration - Loss (0.459) Accuracy (0.860)
# 39 Epoch 400 iteration - Loss (0.285) Accuracy (0.900)
# 39 Epoch 500 iteration - Loss (0.576) Accuracy (0.800)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_19500
# 40 Epoch 100 iteration - Loss (0.353) Accuracy (0.870)
# 40 Epoch 200 iteration - Loss (0.321) Accuracy (0.840)
# 40 Epoch 300 iteration - Loss (0.388) Accuracy (0.840)
# 40 Epoch 400 iteration - Loss (0.352) Accuracy (0.870)
# 40 Epoch 500 iteration - Loss (0.389) Accuracy (0.830)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_20000
# 41 Epoch 100 iteration - Loss (0.328) Accuracy (0.870)
# 41 Epoch 200 iteration - Loss (0.341) Accuracy (0.850)
# 41 Epoch 300 iteration - Loss (0.366) Accuracy (0.870)
# 41 Epoch 400 iteration - Loss (0.378) Accuracy (0.840)
# 41 Epoch 500 iteration - Loss (0.378) Accuracy (0.870)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_20500
# 42 Epoch 100 iteration - Loss (0.332) Accuracy (0.840)
# 42 Epoch 200 iteration - Loss (0.407) Accuracy (0.850)
# 42 Epoch 300 iteration - Loss (0.445) Accuracy (0.850)
# 42 Epoch 400 iteration - Loss (0.478) Accuracy (0.840)
# 42 Epoch 500 iteration - Loss (0.381) Accuracy (0.880)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_21000
# 43 Epoch 100 iteration - Loss (0.280) Accuracy (0.890)
# 43 Epoch 200 iteration - Loss (0.366) Accuracy (0.880)
# 43 Epoch 300 iteration - Loss (0.448) Accuracy (0.810)
# 43 Epoch 400 iteration - Loss (0.356) Accuracy (0.870)
# 43 Epoch 500 iteration - Loss (0.258) Accuracy (0.910)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_21500
# 44 Epoch 100 iteration - Loss (0.341) Accuracy (0.850)
# 44 Epoch 200 iteration - Loss (0.377) Accuracy (0.860)
# 44 Epoch 300 iteration - Loss (0.335) Accuracy (0.840)
# 44 Epoch 400 iteration - Loss (0.284) Accuracy (0.900)
# 44 Epoch 500 iteration - Loss (0.258) Accuracy (0.900)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_22000
# 45 Epoch 100 iteration - Loss (0.322) Accuracy (0.910)
# 45 Epoch 200 iteration - Loss (0.365) Accuracy (0.840)
# 45 Epoch 300 iteration - Loss (0.459) Accuracy (0.780)
# 45 Epoch 400 iteration - Loss (0.369) Accuracy (0.850)
# 45 Epoch 500 iteration - Loss (0.333) Accuracy (0.900)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_22500
# 46 Epoch 100 iteration - Loss (0.317) Accuracy (0.890)
# 46 Epoch 200 iteration - Loss (0.386) Accuracy (0.880)
# 46 Epoch 300 iteration - Loss (0.317) Accuracy (0.870)
# 46 Epoch 400 iteration - Loss (0.394) Accuracy (0.820)
# 46 Epoch 500 iteration - Loss (0.326) Accuracy (0.880)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_23000
# 47 Epoch 100 iteration - Loss (0.346) Accuracy (0.860)
# 47 Epoch 200 iteration - Loss (0.281) Accuracy (0.900)
# 47 Epoch 300 iteration - Loss (0.523) Accuracy (0.850)
# 47 Epoch 400 iteration - Loss (0.338) Accuracy (0.860)
# 47 Epoch 500 iteration - Loss (0.371) Accuracy (0.860)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_23500
# 48 Epoch 100 iteration - Loss (0.204) Accuracy (0.910)
# 48 Epoch 200 iteration - Loss (0.276) Accuracy (0.920)
# 48 Epoch 300 iteration - Loss (0.545) Accuracy (0.800)
# 48 Epoch 400 iteration - Loss (0.468) Accuracy (0.870)
# 48 Epoch 500 iteration - Loss (0.349) Accuracy (0.870)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_24000
# 49 Epoch 100 iteration - Loss (0.261) Accuracy (0.900)
# 49 Epoch 200 iteration - Loss (0.454) Accuracy (0.870)
# 49 Epoch 300 iteration - Loss (0.489) Accuracy (0.850)
# 49 Epoch 400 iteration - Loss (0.318) Accuracy (0.900)
# 49 Epoch 500 iteration - Loss (0.314) Accuracy (0.890)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_24500
# 50 Epoch 100 iteration - Loss (0.489) Accuracy (0.820)
# 50 Epoch 200 iteration - Loss (0.305) Accuracy (0.850)
# 50 Epoch 300 iteration - Loss (0.335) Accuracy (0.870)
# 50 Epoch 400 iteration - Loss (0.331) Accuracy (0.880)
# 50 Epoch 500 iteration - Loss (0.341) Accuracy (0.870)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_25000
# 51 Epoch 100 iteration - Loss (0.223) Accuracy (0.940)
# 51 Epoch 200 iteration - Loss (0.264) Accuracy (0.920)
# 51 Epoch 300 iteration - Loss (0.460) Accuracy (0.830)
# 51 Epoch 400 iteration - Loss (0.561) Accuracy (0.820)
# 51 Epoch 500 iteration - Loss (0.293) Accuracy (0.910)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_25500
# 52 Epoch 100 iteration - Loss (0.408) Accuracy (0.850)
# 52 Epoch 200 iteration - Loss (0.398) Accuracy (0.870)
# 52 Epoch 300 iteration - Loss (0.521) Accuracy (0.860)
# 52 Epoch 400 iteration - Loss (0.323) Accuracy (0.810)
# 52 Epoch 500 iteration - Loss (0.248) Accuracy (0.900)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_26000
# 53 Epoch 100 iteration - Loss (0.378) Accuracy (0.860)
# 53 Epoch 200 iteration - Loss (0.344) Accuracy (0.840)
# 53 Epoch 300 iteration - Loss (0.469) Accuracy (0.840)
# 53 Epoch 400 iteration - Loss (0.376) Accuracy (0.890)
# 53 Epoch 500 iteration - Loss (0.355) Accuracy (0.840)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_26500
# 54 Epoch 100 iteration - Loss (0.246) Accuracy (0.910)
# 54 Epoch 200 iteration - Loss (0.241) Accuracy (0.910)
# 54 Epoch 300 iteration - Loss (0.535) Accuracy (0.800)
# 54 Epoch 400 iteration - Loss (0.393) Accuracy (0.890)
# 54 Epoch 500 iteration - Loss (0.334) Accuracy (0.870)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_27000
# 55 Epoch 100 iteration - Loss (0.359) Accuracy (0.900)
# 55 Epoch 200 iteration - Loss (0.340) Accuracy (0.870)
# 55 Epoch 300 iteration - Loss (0.460) Accuracy (0.840)
# 55 Epoch 400 iteration - Loss (0.192) Accuracy (0.930)
# 55 Epoch 500 iteration - Loss (0.247) Accuracy (0.890)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_27500
# 56 Epoch 100 iteration - Loss (0.208) Accuracy (0.910)
# 56 Epoch 200 iteration - Loss (0.398) Accuracy (0.860)
# 56 Epoch 300 iteration - Loss (0.479) Accuracy (0.820)
# 56 Epoch 400 iteration - Loss (0.249) Accuracy (0.920)
# 56 Epoch 500 iteration - Loss (0.368) Accuracy (0.870)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_28000
# 57 Epoch 100 iteration - Loss (0.205) Accuracy (0.940)
# 57 Epoch 200 iteration - Loss (0.291) Accuracy (0.860)
# 57 Epoch 300 iteration - Loss (0.337) Accuracy (0.920)
# 57 Epoch 400 iteration - Loss (0.295) Accuracy (0.880)
# 57 Epoch 500 iteration - Loss (0.375) Accuracy (0.890)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_28500
# 58 Epoch 100 iteration - Loss (0.281) Accuracy (0.900)
# 58 Epoch 200 iteration - Loss (0.174) Accuracy (0.960)
# 58 Epoch 300 iteration - Loss (0.380) Accuracy (0.830)
# 58 Epoch 400 iteration - Loss (0.184) Accuracy (0.950)
# 58 Epoch 500 iteration - Loss (0.290) Accuracy (0.870)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_29000
# 59 Epoch 100 iteration - Loss (0.212) Accuracy (0.910)
# 59 Epoch 200 iteration - Loss (0.299) Accuracy (0.880)
# 59 Epoch 300 iteration - Loss (0.416) Accuracy (0.860)
# 59 Epoch 400 iteration - Loss (0.330) Accuracy (0.850)
# 59 Epoch 500 iteration - Loss (0.314) Accuracy (0.920)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_29500
# 60 Epoch 100 iteration - Loss (0.214) Accuracy (0.910)
# 60 Epoch 200 iteration - Loss (0.280) Accuracy (0.900)
# 60 Epoch 300 iteration - Loss (0.496) Accuracy (0.850)
# 60 Epoch 400 iteration - Loss (0.211) Accuracy (0.920)
# 60 Epoch 500 iteration - Loss (0.332) Accuracy (0.920)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_30000
# 61 Epoch 100 iteration - Loss (0.369) Accuracy (0.850)
# 61 Epoch 200 iteration - Loss (0.265) Accuracy (0.900)
# 61 Epoch 300 iteration - Loss (0.215) Accuracy (0.920)
# 61 Epoch 400 iteration - Loss (0.390) Accuracy (0.860)
# 61 Epoch 500 iteration - Loss (0.324) Accuracy (0.880)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_30500
# 62 Epoch 100 iteration - Loss (0.165) Accuracy (0.940)
# 62 Epoch 200 iteration - Loss (0.283) Accuracy (0.910)
# 62 Epoch 300 iteration - Loss (0.327) Accuracy (0.860)
# 62 Epoch 400 iteration - Loss (0.234) Accuracy (0.900)
# 62 Epoch 500 iteration - Loss (0.317) Accuracy (0.880)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_31000
# 63 Epoch 100 iteration - Loss (0.260) Accuracy (0.910)
# 63 Epoch 200 iteration - Loss (0.227) Accuracy (0.920)
# 63 Epoch 300 iteration - Loss (0.542) Accuracy (0.830)
# 63 Epoch 400 iteration - Loss (0.294) Accuracy (0.860)
# 63 Epoch 500 iteration - Loss (0.358) Accuracy (0.890)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_31500
# 64 Epoch 100 iteration - Loss (0.257) Accuracy (0.930)
# 64 Epoch 200 iteration - Loss (0.283) Accuracy (0.900)
# 64 Epoch 300 iteration - Loss (0.401) Accuracy (0.830)
# 64 Epoch 400 iteration - Loss (0.236) Accuracy (0.950)
# 64 Epoch 500 iteration - Loss (0.207) Accuracy (0.930)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_32000
# 65 Epoch 100 iteration - Loss (0.328) Accuracy (0.880)
# 65 Epoch 200 iteration - Loss (0.276) Accuracy (0.920)
# 65 Epoch 300 iteration - Loss (0.429) Accuracy (0.850)
# 65 Epoch 400 iteration - Loss (0.222) Accuracy (0.910)
# 65 Epoch 500 iteration - Loss (0.378) Accuracy (0.820)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_32500
# 66 Epoch 100 iteration - Loss (0.366) Accuracy (0.910)
# 66 Epoch 200 iteration - Loss (0.207) Accuracy (0.920)
# 66 Epoch 300 iteration - Loss (0.383) Accuracy (0.900)
# 66 Epoch 400 iteration - Loss (0.219) Accuracy (0.920)
# 66 Epoch 500 iteration - Loss (0.228) Accuracy (0.880)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_33000
# 67 Epoch 100 iteration - Loss (0.320) Accuracy (0.920)
# 67 Epoch 200 iteration - Loss (0.316) Accuracy (0.860)
# 67 Epoch 300 iteration - Loss (0.361) Accuracy (0.870)
# 67 Epoch 400 iteration - Loss (0.447) Accuracy (0.850)
# 67 Epoch 500 iteration - Loss (0.323) Accuracy (0.890)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_33500
# 68 Epoch 100 iteration - Loss (0.232) Accuracy (0.920)
# 68 Epoch 200 iteration - Loss (0.285) Accuracy (0.900)
# 68 Epoch 300 iteration - Loss (0.287) Accuracy (0.860)
# 68 Epoch 400 iteration - Loss (0.287) Accuracy (0.880)
# 68 Epoch 500 iteration - Loss (0.293) Accuracy (0.880)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_34000
# 69 Epoch 100 iteration - Loss (0.233) Accuracy (0.910)
# 69 Epoch 200 iteration - Loss (0.302) Accuracy (0.920)
# 69 Epoch 300 iteration - Loss (0.393) Accuracy (0.830)
# 69 Epoch 400 iteration - Loss (0.483) Accuracy (0.820)
# 69 Epoch 500 iteration - Loss (0.276) Accuracy (0.910)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_34500
# 70 Epoch 100 iteration - Loss (0.186) Accuracy (0.920)
# 70 Epoch 200 iteration - Loss (0.358) Accuracy (0.840)
# 70 Epoch 300 iteration - Loss (0.436) Accuracy (0.840)
# 70 Epoch 400 iteration - Loss (0.345) Accuracy (0.890)
# 70 Epoch 500 iteration - Loss (0.253) Accuracy (0.900)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_35000
# 71 Epoch 100 iteration - Loss (0.247) Accuracy (0.900)
# 71 Epoch 200 iteration - Loss (0.226) Accuracy (0.920)
# 71 Epoch 300 iteration - Loss (0.314) Accuracy (0.870)
# 71 Epoch 400 iteration - Loss (0.351) Accuracy (0.890)
# 71 Epoch 500 iteration - Loss (0.294) Accuracy (0.870)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_35500
# 72 Epoch 100 iteration - Loss (0.227) Accuracy (0.910)
# 72 Epoch 200 iteration - Loss (0.168) Accuracy (0.930)
# 72 Epoch 300 iteration - Loss (0.331) Accuracy (0.890)
# 72 Epoch 400 iteration - Loss (0.240) Accuracy (0.910)
# 72 Epoch 500 iteration - Loss (0.172) Accuracy (0.920)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_36000
# 73 Epoch 100 iteration - Loss (0.351) Accuracy (0.870)
# 73 Epoch 200 iteration - Loss (0.284) Accuracy (0.890)
# 73 Epoch 300 iteration - Loss (0.360) Accuracy (0.860)
# 73 Epoch 400 iteration - Loss (0.245) Accuracy (0.890)
# 73 Epoch 500 iteration - Loss (0.292) Accuracy (0.890)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_36500
# 74 Epoch 100 iteration - Loss (0.237) Accuracy (0.940)
# 74 Epoch 200 iteration - Loss (0.359) Accuracy (0.900)
# 74 Epoch 300 iteration - Loss (0.255) Accuracy (0.870)
# 74 Epoch 400 iteration - Loss (0.291) Accuracy (0.900)
# 74 Epoch 500 iteration - Loss (0.163) Accuracy (0.930)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_37000
# 75 Epoch 100 iteration - Loss (0.240) Accuracy (0.900)
# 75 Epoch 200 iteration - Loss (0.221) Accuracy (0.930)
# 75 Epoch 300 iteration - Loss (0.382) Accuracy (0.860)
# 75 Epoch 400 iteration - Loss (0.293) Accuracy (0.870)
# 75 Epoch 500 iteration - Loss (0.260) Accuracy (0.950)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_37500
# 76 Epoch 100 iteration - Loss (0.191) Accuracy (0.930)
# 76 Epoch 200 iteration - Loss (0.275) Accuracy (0.870)
# 76 Epoch 300 iteration - Loss (0.338) Accuracy (0.890)
# 76 Epoch 400 iteration - Loss (0.325) Accuracy (0.880)
# 76 Epoch 500 iteration - Loss (0.268) Accuracy (0.900)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_38000
# 77 Epoch 100 iteration - Loss (0.175) Accuracy (0.940)
# 77 Epoch 200 iteration - Loss (0.311) Accuracy (0.860)
# 77 Epoch 300 iteration - Loss (0.347) Accuracy (0.880)
# 77 Epoch 400 iteration - Loss (0.280) Accuracy (0.930)
# 77 Epoch 500 iteration - Loss (0.281) Accuracy (0.930)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_38500
# 78 Epoch 100 iteration - Loss (0.240) Accuracy (0.910)
# 78 Epoch 200 iteration - Loss (0.189) Accuracy (0.940)
# 78 Epoch 300 iteration - Loss (0.270) Accuracy (0.860)
# 78 Epoch 400 iteration - Loss (0.280) Accuracy (0.890)
# 78 Epoch 500 iteration - Loss (0.158) Accuracy (0.950)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_39000
# 79 Epoch 100 iteration - Loss (0.156) Accuracy (0.940)
# 79 Epoch 200 iteration - Loss (0.281) Accuracy (0.910)
# 79 Epoch 300 iteration - Loss (0.297) Accuracy (0.880)
# 79 Epoch 400 iteration - Loss (0.286) Accuracy (0.900)
# 79 Epoch 500 iteration - Loss (0.172) Accuracy (0.940)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_39500
# 80 Epoch 100 iteration - Loss (0.355) Accuracy (0.880)
# 80 Epoch 200 iteration - Loss (0.348) Accuracy (0.870)
# 80 Epoch 300 iteration - Loss (0.262) Accuracy (0.890)
# 80 Epoch 400 iteration - Loss (0.230) Accuracy (0.920)
# 80 Epoch 500 iteration - Loss (0.241) Accuracy (0.930)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_40000
# 81 Epoch 100 iteration - Loss (0.173) Accuracy (0.940)
# 81 Epoch 200 iteration - Loss (0.218) Accuracy (0.910)
# 81 Epoch 300 iteration - Loss (0.255) Accuracy (0.910)
# 81 Epoch 400 iteration - Loss (0.254) Accuracy (0.920)
# 81 Epoch 500 iteration - Loss (0.259) Accuracy (0.890)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_40500
# 82 Epoch 100 iteration - Loss (0.282) Accuracy (0.940)
# 82 Epoch 200 iteration - Loss (0.165) Accuracy (0.940)
# 82 Epoch 300 iteration - Loss (0.211) Accuracy (0.920)
# 82 Epoch 400 iteration - Loss (0.172) Accuracy (0.930)
# 82 Epoch 500 iteration - Loss (0.218) Accuracy (0.930)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_41000
# 83 Epoch 100 iteration - Loss (0.235) Accuracy (0.910)
# 83 Epoch 200 iteration - Loss (0.233) Accuracy (0.910)
# 83 Epoch 300 iteration - Loss (0.246) Accuracy (0.900)
# 83 Epoch 400 iteration - Loss (0.311) Accuracy (0.920)
# 83 Epoch 500 iteration - Loss (0.265) Accuracy (0.890)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_41500
# 84 Epoch 100 iteration - Loss (0.427) Accuracy (0.910)
# 84 Epoch 200 iteration - Loss (0.223) Accuracy (0.890)
# 84 Epoch 300 iteration - Loss (0.234) Accuracy (0.930)
# 84 Epoch 400 iteration - Loss (0.200) Accuracy (0.930)
# 84 Epoch 500 iteration - Loss (0.204) Accuracy (0.910)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_42000
# 85 Epoch 100 iteration - Loss (0.260) Accuracy (0.930)
# 85 Epoch 200 iteration - Loss (0.310) Accuracy (0.910)
# 85 Epoch 300 iteration - Loss (0.351) Accuracy (0.870)
# 85 Epoch 400 iteration - Loss (0.300) Accuracy (0.890)
# 85 Epoch 500 iteration - Loss (0.130) Accuracy (0.960)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_42500
# 86 Epoch 100 iteration - Loss (0.411) Accuracy (0.890)
# 86 Epoch 200 iteration - Loss (0.263) Accuracy (0.890)
# 86 Epoch 300 iteration - Loss (0.278) Accuracy (0.880)
# 86 Epoch 400 iteration - Loss (0.217) Accuracy (0.900)
# 86 Epoch 500 iteration - Loss (0.292) Accuracy (0.900)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_43000
# 87 Epoch 100 iteration - Loss (0.188) Accuracy (0.930)
# 87 Epoch 200 iteration - Loss (0.185) Accuracy (0.940)
# 87 Epoch 300 iteration - Loss (0.263) Accuracy (0.910)
# 87 Epoch 400 iteration - Loss (0.121) Accuracy (0.960)
# 87 Epoch 500 iteration - Loss (0.253) Accuracy (0.880)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_43500
# 88 Epoch 100 iteration - Loss (0.128) Accuracy (0.980)
# 88 Epoch 200 iteration - Loss (0.263) Accuracy (0.890)
# 88 Epoch 300 iteration - Loss (0.184) Accuracy (0.920)
# 88 Epoch 400 iteration - Loss (0.219) Accuracy (0.930)
# 88 Epoch 500 iteration - Loss (0.255) Accuracy (0.920)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_44000
# 89 Epoch 100 iteration - Loss (0.222) Accuracy (0.930)
# 89 Epoch 200 iteration - Loss (0.164) Accuracy (0.930)
# 89 Epoch 300 iteration - Loss (0.209) Accuracy (0.920)
# 89 Epoch 400 iteration - Loss (0.161) Accuracy (0.960)
# 89 Epoch 500 iteration - Loss (0.442) Accuracy (0.850)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_44500
# 90 Epoch 100 iteration - Loss (0.259) Accuracy (0.910)
# 90 Epoch 200 iteration - Loss (0.184) Accuracy (0.930)
# 90 Epoch 300 iteration - Loss (0.325) Accuracy (0.910)
# 90 Epoch 400 iteration - Loss (0.145) Accuracy (0.950)
# 90 Epoch 500 iteration - Loss (0.308) Accuracy (0.880)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_45000
# 91 Epoch 100 iteration - Loss (0.265) Accuracy (0.890)
# 91 Epoch 200 iteration - Loss (0.240) Accuracy (0.950)
# 91 Epoch 300 iteration - Loss (0.307) Accuracy (0.890)
# 91 Epoch 400 iteration - Loss (0.203) Accuracy (0.940)
# 91 Epoch 500 iteration - Loss (0.298) Accuracy (0.910)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_45500
# 92 Epoch 100 iteration - Loss (0.218) Accuracy (0.910)
# 92 Epoch 200 iteration - Loss (0.112) Accuracy (0.950)
# 92 Epoch 300 iteration - Loss (0.278) Accuracy (0.890)
# 92 Epoch 400 iteration - Loss (0.217) Accuracy (0.890)
# 92 Epoch 500 iteration - Loss (0.376) Accuracy (0.900)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_46000
# 93 Epoch 100 iteration - Loss (0.177) Accuracy (0.940)
# 93 Epoch 200 iteration - Loss (0.265) Accuracy (0.890)
# 93 Epoch 300 iteration - Loss (0.425) Accuracy (0.870)
# 93 Epoch 400 iteration - Loss (0.176) Accuracy (0.960)
# 93 Epoch 500 iteration - Loss (0.224) Accuracy (0.910)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_46500
# 94 Epoch 100 iteration - Loss (0.281) Accuracy (0.910)
# 94 Epoch 200 iteration - Loss (0.194) Accuracy (0.920)
# 94 Epoch 300 iteration - Loss (0.356) Accuracy (0.860)
# 94 Epoch 400 iteration - Loss (0.225) Accuracy (0.950)
# 94 Epoch 500 iteration - Loss (0.294) Accuracy (0.920)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_47000
# 95 Epoch 100 iteration - Loss (0.142) Accuracy (0.950)
# 95 Epoch 200 iteration - Loss (0.170) Accuracy (0.910)
# 95 Epoch 300 iteration - Loss (0.285) Accuracy (0.850)
# 95 Epoch 400 iteration - Loss (0.220) Accuracy (0.920)
# 95 Epoch 500 iteration - Loss (0.215) Accuracy (0.940)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_47500
# 96 Epoch 100 iteration - Loss (0.166) Accuracy (0.950)
# 96 Epoch 200 iteration - Loss (0.224) Accuracy (0.930)
# 96 Epoch 300 iteration - Loss (0.206) Accuracy (0.910)
# 96 Epoch 400 iteration - Loss (0.272) Accuracy (0.930)
# 96 Epoch 500 iteration - Loss (0.122) Accuracy (0.960)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_48000
# 97 Epoch 100 iteration - Loss (0.155) Accuracy (0.950)
# 97 Epoch 200 iteration - Loss (0.187) Accuracy (0.950)
# 97 Epoch 300 iteration - Loss (0.280) Accuracy (0.880)
# 97 Epoch 400 iteration - Loss (0.220) Accuracy (0.920)
# 97 Epoch 500 iteration - Loss (0.201) Accuracy (0.890)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_48500
# 98 Epoch 100 iteration - Loss (0.243) Accuracy (0.930)
# 98 Epoch 200 iteration - Loss (0.192) Accuracy (0.940)
# 98 Epoch 300 iteration - Loss (0.242) Accuracy (0.930)
# 98 Epoch 400 iteration - Loss (0.179) Accuracy (0.920)
# 98 Epoch 500 iteration - Loss (0.192) Accuracy (0.920)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_49000
# 99 Epoch 100 iteration - Loss (0.193) Accuracy (0.910)
# 99 Epoch 200 iteration - Loss (0.201) Accuracy (0.910)
# 99 Epoch 300 iteration - Loss (0.195) Accuracy (0.930)
# 99 Epoch 400 iteration - Loss (0.262) Accuracy (0.890)
# 99 Epoch 500 iteration - Loss (0.163) Accuracy (0.900)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_49500
# 100 Epoch 100 iteration - Loss (0.154) Accuracy (0.930)
# 100 Epoch 200 iteration - Loss (0.253) Accuracy (0.900)
# 100 Epoch 300 iteration - Loss (0.264) Accuracy (0.910)
# 100 Epoch 400 iteration - Loss (0.091) Accuracy (0.980)
# 100 Epoch 500 iteration - Loss (0.132) Accuracy (0.940)
# Saved checkpoint cifar10_ramdom-init_checkpoints/cifar10_cnn_50000

# %% [markdown]
# ### Evaluating the model

# %%
# Manually set the checkpoint path
#checkpoint_path = 'cifar10_checkpoints/cifar10_cnn-5000'
# Automatically find the last checkpoint
checkpoint_path = tf.train.latest_checkpoint(checkpoint_dir='cifar10_ramdom-init_checkpoints/')
print('Last checkpoint path is %s' % (checkpoint_path))
# Out:
# Last checkpoint path is cifar10_ramdom-init_checkpoints/cifar10_cnn-50000

# %%
#with tf.Session() as sess:
tf.reset_default_graph()

# Open the session
sess = tf.Session()
sess.run(tf.global_variables_initializer())

"""Evaluation model"""
# build input placeholders
images, labels = build_inputs(batch_size, loader.get_image_size())

# Build a Graph that computes the logits predictions from the
# inference model.
logits = build_model(images)

# Calculate loss.
loss = build_loss(logits, labels)

# Build a Graph that trains the model with one batch of examples and
# updates the model parameters.
train_op, global_step = build_train_operation(loss)

# Build the accuracy and correct number of examples
# to check model is learned correctly while training
accuracy, correct_num, prediction = build_accuracy(logits, labels)

# Create Saver-object to save and reload the model later
saver = tf.train.Saver()
# Load the checkpoint or initialize the variables
if checkpoint_path != '':
    saver.restore(sess, save_path=checkpoint_path)
    print('Model is restored from %s' % checkpoint_path)
else:
    sess.run(tf.global_variables_initializer())

loader.reset()
num_correct = 0
num_examples = 0   

# Evaluate the model
while True:
    # Load a batch data
    batch = loader.get_batch(batch_size, 'test')
    if batch['wrapped']: break
    
    # Compute the correct numbers
    batch_acc, batch_correct_num = sess.run([accuracy, correct_num], 
                                            feed_dict={images:batch['images'],
                                                       labels:batch['labels']})

    num_correct += batch_correct_num
    num_examples += batch_size
    
print('Test accuracy: %.2f%%' % (float(num_correct) / float(num_examples) * 100.0))

sess.close()
# Out:
# INFO:tensorflow:Restoring parameters from cifar10_ramdom-init_checkpoints/cifar10_cnn-50000
# Model is restored from cifar10_ramdom-init_checkpoints/cifar10_cnn-50000
# Test accuracy: 65.44%

# %% [markdown]
# ### Visualization
# Plot the images and predicted & true labels

# %%
sess = tf.Session()
saver.restore(sess, save_path=checkpoint_path)

loader.reset()
# Out:
# INFO:tensorflow:Restoring parameters from cifar10_ramdom-init_checkpoints/cifar10_cnn-50000

# %%
batch = loader.get_batch(batch_size, 'test')
realized_prediction = sess.run([prediction], feed_dict={images:batch['images'],labels:batch['labels']})
fig = plot_images(batch['images'][:9], batch['labels'][:9], loader.get_class_names(), realized_prediction[0][:9])
fig.show()
# Out:
# /home/pirl/anaconda2/envs/vision/lib/python3.6/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
tf.reset_default_graph()
sess.close()
