# %% [markdown]
# # MNIST

# %% [markdown]
# ### MNIST 데이터 받기

# %%
import os
import sys
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("data/", one_hot=True)
train_data = mnist.train.images
train_label = mnist.train.labels
test_data = mnist.test.images
test_label = mnist.test.labels
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ### MNIST 데이터 확인하기

# %%
# size of MNIST
print(train_data.shape)
print(train_label.shape)
print(test_data.shape)
print(test_label.shape)
# Out:
# (55000, 784)
# (55000, 10)
# (10000, 784)
# (10000, 10)

# %% [markdown]
# ### Data Pre-processing (데이터 전처리)

# %% [markdown]
# # Implementation (1)
#
#
# ## Loss function (손실 함수) : Cross Entropy
#
# # <center> \\( L(y_i, f(x_i; W)) = -\frac{1}{n}\sum_{i=1}^{n}\sum_{k=1} y_{i,j} log(f(x_i)_k)\\)</center>
#
#
# #### get_cross_entropy_loss 함수의 내용을 완성하세요.
# #### (Hint : (1) tf.reduce_mean(), tf.reduce_sum(), tf.log() (2) Tensor dimension에 유의 (3) log 함수 사용 시 epsilon 사용하세요.)

# %%
def get_cross_entropy_loss(y_true, y_hat, epsilon=1e-8):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('cross_entropy'):
        loss = -tf.reduce_mean(tf.reduce_sum(y_true * tf.log(y_hat),axis = 1))
    return loss

# %%
def get_accuracy(y_true, y_hat):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('accuracy'):
        # Compare the highest indices between the predicted label and the true label
        correct_prediction = tf.equal(tf.argmax(y_hat, 1), tf.argmax(y_true, 1), name='correct_prediction')
        # Compute accuracy
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')
    return accuracy



# y_true = tf.placeholder(tf.float32, [None, 10])
# y_hat = tf.placeholder(tf.float32, [None, 10])
# get_cross_entropy_loss(y_true, y_hat)

# %% [markdown]
# ## Hyper-parameter (하이퍼 파라미터)

# %%
# Set hypyerparameters
learning_rate = 0.01
max_iter = 2000
batch_size = 100

# %% [markdown]
# # Implementation (2)
# ## Linear Classifier (선형 분류기)
#
# ## <center> \\( f(x) = W^Tx+b \\)</center>
#
# ### linear function을 완성하세요.
# ### (Hint : (1) weight, bias 선언 (2) tf.get_variable()의 initializer  (3) tf.matmul())

# %%
def fc(name, out_dim, inputs):
    """
    Args :
        Inputs : Input tensor
        out_dim : output dimension
        
    Returns:
        inputs * weight + bias
    """

    with tf.variable_scope(name):
        shp = inputs.get_shape().as_list()[1]
        initial = tf.truncated_normal([shp,out_dim], stddev=.01) # 정규분포에서 양 꼬리를 자른것 
        weights = tf.get_variable('w', initializer=initial)
        y_hat = tf.matmul(inputs, weights)   # 순서가 XW이다.


    return y_hat

# %% [markdown]
# # Implementation (3)
#
# ## Model Setting
#
# ### 1. Training data 및 Test data의 각각의 image를 한 vector로 만들어서 train_data, test_data에 각각 저장하세요.
# #### Hint) 데이터 차원.
# ### 2. Dataset로부터 받은 데이터(Image, label)를 담을 변수를 각각 x 및 y_true에 선언하세요.
# #### Hint) tf.placeholder
# ### 3. Implementation (2)에서 구현한 linear classifier 함수값과 softmax 함수를 통한 prediction 값을 y_hat에 저장하세요.
# #### Hint) tf.nn.softmax
# ### 4. 3으로부터 얻은 결과를 통해 Implementation (1)에서 구현한 loss function을 통해 얻은 loss를 cross_entropy에 저장하세요.

# %%
tf.reset_default_graph()
# Flatten data
###################################################################
#                    Implementation 3-1                           #
###################################################################
#train_data = None
#test_data = None

###################################################################
#                    Implementation 3-2                           #
###################################################################
x = tf.placeholder(tf.float32, [None, 784])
y_true = tf.placeholder(tf.float32, [None, 10])

###################################################################
#                    Implementation 3-3                          #
###################################################################
h1 = fc('layer1', 512, x)
y_logits = fc('layer2', 10 ,h1)
y_hat = tf.nn.softmax(y_logits)
###################################################################
#                    Implementation 3-4                           #
###################################################################
cross_entropy = get_cross_entropy_loss(y_true, y_hat)

# Calculate accuracy
accuracy = get_accuracy(y_true, y_hat)
# Make gradient descent op
train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(cross_entropy)

# Make op to initialize declared variable
init = tf.global_variables_initializer()

with tf.Session() as sess:
    # Initialize variables
    sess.run(init)
    
    # Training
    for step in range(max_iter):
        # Get batch data and label
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # train the network and calculate cross entropy
        _, loss = sess.run([train_step, cross_entropy], feed_dict={x: batch_x, y_true: batch_y})
        # calcualte accuracy
        acc = sess.run(accuracy, feed_dict={x: test_data, y_true: test_label})
        # print loss (cross entropy) and accuracy at every 10th step
        if (step + 1) % 10 == 0:
            print("{}th iteration, loss: {:.4f}, test accuracy: {:.4f}".format(step + 1, loss, acc))
# Out:
# 10th iteration, loss: 2.2964, test accuracy: 0.1536
# 20th iteration, loss: 2.2881, test accuracy: 0.3085
# 30th iteration, loss: 2.2777, test accuracy: 0.4859
# 40th iteration, loss: 2.2696, test accuracy: 0.5612
# 50th iteration, loss: 2.2577, test accuracy: 0.6195
# 60th iteration, loss: 2.2432, test accuracy: 0.6251
# 70th iteration, loss: 2.2486, test accuracy: 0.6440
# 80th iteration, loss: 2.2339, test accuracy: 0.6595
# 90th iteration, loss: 2.2280, test accuracy: 0.6598
# 100th iteration, loss: 2.2084, test accuracy: 0.6652
# 110th iteration, loss: 2.1988, test accuracy: 0.6646
# 120th iteration, loss: 2.1807, test accuracy: 0.6703
# 130th iteration, loss: 2.1902, test accuracy: 0.6714
# 140th iteration, loss: 2.1574, test accuracy: 0.6669
# 150th iteration, loss: 2.1567, test accuracy: 0.6759
# 160th iteration, loss: 2.1368, test accuracy: 0.6846
# 170th iteration, loss: 2.1224, test accuracy: 0.6867
# 180th iteration, loss: 2.0985, test accuracy: 0.6816
# 190th iteration, loss: 2.0610, test accuracy: 0.6796
# 200th iteration, loss: 2.0860, test accuracy: 0.6935
# 210th iteration, loss: 2.0552, test accuracy: 0.6940
# 220th iteration, loss: 2.0530, test accuracy: 0.6930
# 230th iteration, loss: 1.9822, test accuracy: 0.7021
# 240th iteration, loss: 2.0112, test accuracy: 0.7038
# 250th iteration, loss: 1.9741, test accuracy: 0.7045
# 260th iteration, loss: 1.9497, test accuracy: 0.7043
# 270th iteration, loss: 1.9051, test accuracy: 0.7102
# 280th iteration, loss: 1.8859, test accuracy: 0.7063
# 290th iteration, loss: 1.8908, test accuracy: 0.7111
# 300th iteration, loss: 1.7973, test accuracy: 0.7102
# 310th iteration, loss: 1.7747, test accuracy: 0.7054
# 320th iteration, loss: 1.8087, test accuracy: 0.7098
# 330th iteration, loss: 1.7536, test accuracy: 0.7158
# 340th iteration, loss: 1.7799, test accuracy: 0.7178
# 350th iteration, loss: 1.6360, test accuracy: 0.7146
# 360th iteration, loss: 1.6176, test accuracy: 0.7145
# 370th iteration, loss: 1.5889, test accuracy: 0.7122
# 380th iteration, loss: 1.5908, test accuracy: 0.7162
# 390th iteration, loss: 1.5171, test accuracy: 0.7197
# 400th iteration, loss: 1.5391, test accuracy: 0.7204
# 410th iteration, loss: 1.4262, test accuracy: 0.7241
# 420th iteration, loss: 1.5249, test accuracy: 0.7284
# 430th iteration, loss: 1.4558, test accuracy: 0.7332
# 440th iteration, loss: 1.3614, test accuracy: 0.7357
# 450th iteration, loss: 1.3513, test accuracy: 0.7384
# 460th iteration, loss: 1.2881, test accuracy: 0.7398
# 470th iteration, loss: 1.3622, test accuracy: 0.7410
# 480th iteration, loss: 1.2692, test accuracy: 0.7479
# 490th iteration, loss: 1.3785, test accuracy: 0.7522
# 500th iteration, loss: 1.3666, test accuracy: 0.7552
# 510th iteration, loss: 1.2335, test accuracy: 0.7584
# 520th iteration, loss: 1.2356, test accuracy: 0.7627
# 530th iteration, loss: 1.1494, test accuracy: 0.7618
# 540th iteration, loss: 1.1065, test accuracy: 0.7645
# 550th iteration, loss: 1.0009, test accuracy: 0.7654
# 560th iteration, loss: 1.1486, test accuracy: 0.7697
# 570th iteration, loss: 1.1038, test accuracy: 0.7758
# 580th iteration, loss: 1.0173, test accuracy: 0.7782
# 590th iteration, loss: 1.0869, test accuracy: 0.7821
# 600th iteration, loss: 1.1393, test accuracy: 0.7849
# 610th iteration, loss: 1.2220, test accuracy: 0.7880
# 620th iteration, loss: 1.0046, test accuracy: 0.7927
# 630th iteration, loss: 0.8945, test accuracy: 0.7927
# 640th iteration, loss: 1.0058, test accuracy: 0.7936
# 650th iteration, loss: 0.9273, test accuracy: 0.7983
# 660th iteration, loss: 0.9611, test accuracy: 0.8005
# 670th iteration, loss: 0.8196, test accuracy: 0.8013
# 680th iteration, loss: 0.8319, test accuracy: 0.8023
# 690th iteration, loss: 0.9135, test accuracy: 0.8067
# 700th iteration, loss: 0.9725, test accuracy: 0.8115
# 710th iteration, loss: 0.8229, test accuracy: 0.8132
# 720th iteration, loss: 0.8288, test accuracy: 0.8152
# 730th iteration, loss: 0.8707, test accuracy: 0.8159
# 740th iteration, loss: 0.8639, test accuracy: 0.8186
# 750th iteration, loss: 0.7195, test accuracy: 0.8198
# 760th iteration, loss: 0.9080, test accuracy: 0.8222
# 770th iteration, loss: 0.9251, test accuracy: 0.8236
# 780th iteration, loss: 0.6757, test accuracy: 0.8237
# 790th iteration, loss: 0.8265, test accuracy: 0.8258
# 800th iteration, loss: 0.7215, test accuracy: 0.8265
# 810th iteration, loss: 0.8224, test accuracy: 0.8281
# 820th iteration, loss: 0.7306, test accuracy: 0.8290
# 830th iteration, loss: 0.7632, test accuracy: 0.8300
# 840th iteration, loss: 0.8222, test accuracy: 0.8311
# 850th iteration, loss: 0.7612, test accuracy: 0.8326
# 860th iteration, loss: 0.7759, test accuracy: 0.8332
# 870th iteration, loss: 0.6632, test accuracy: 0.8360
# 880th iteration, loss: 0.7285, test accuracy: 0.8335
# 890th iteration, loss: 0.6813, test accuracy: 0.8358
# 900th iteration, loss: 0.7503, test accuracy: 0.8374
# 910th iteration, loss: 0.7140, test accuracy: 0.8389
# 920th iteration, loss: 0.6907, test accuracy: 0.8398
# 930th iteration, loss: 0.6749, test accuracy: 0.8402
# 940th iteration, loss: 0.5799, test accuracy: 0.8423
# 950th iteration, loss: 0.7450, test accuracy: 0.8426
# 960th iteration, loss: 0.6836, test accuracy: 0.8418
# 970th iteration, loss: 0.5905, test accuracy: 0.8438
# 980th iteration, loss: 0.8764, test accuracy: 0.8450
# 990th iteration, loss: 0.6267, test accuracy: 0.8455
# 1000th iteration, loss: 0.6927, test accuracy: 0.8473
# 1010th iteration, loss: 0.6384, test accuracy: 0.8470
# 1020th iteration, loss: 0.5833, test accuracy: 0.8479
# 1030th iteration, loss: 0.5928, test accuracy: 0.8489
# 1040th iteration, loss: 0.6568, test accuracy: 0.8493
# 1050th iteration, loss: 0.6118, test accuracy: 0.8514
# 1060th iteration, loss: 0.6042, test accuracy: 0.8530
# 1070th iteration, loss: 0.6554, test accuracy: 0.8527
# 1080th iteration, loss: 0.5849, test accuracy: 0.8546
# 1090th iteration, loss: 0.5918, test accuracy: 0.8531
# 1100th iteration, loss: 0.5608, test accuracy: 0.8551
# 1110th iteration, loss: 0.6072, test accuracy: 0.8545
# 1120th iteration, loss: 0.6231, test accuracy: 0.8548
# 1130th iteration, loss: 0.6836, test accuracy: 0.8565
# 1140th iteration, loss: 0.6370, test accuracy: 0.8577
# 1150th iteration, loss: 0.5740, test accuracy: 0.8581
# 1160th iteration, loss: 0.5533, test accuracy: 0.8592
# 1170th iteration, loss: 0.5672, test accuracy: 0.8598
# 1180th iteration, loss: 0.5162, test accuracy: 0.8595
# 1190th iteration, loss: 0.5815, test accuracy: 0.8594
# 1200th iteration, loss: 0.4962, test accuracy: 0.8600
# 1210th iteration, loss: 0.6486, test accuracy: 0.8613
# 1220th iteration, loss: 0.5674, test accuracy: 0.8619
# 1230th iteration, loss: 0.5559, test accuracy: 0.8622
# 1240th iteration, loss: 0.4958, test accuracy: 0.8620
# 1250th iteration, loss: 0.6343, test accuracy: 0.8626
# 1260th iteration, loss: 0.4984, test accuracy: 0.8634
# 1270th iteration, loss: 0.5079, test accuracy: 0.8643
# 1280th iteration, loss: 0.5641, test accuracy: 0.8644
# 1290th iteration, loss: 0.5091, test accuracy: 0.8657
# 1300th iteration, loss: 0.5557, test accuracy: 0.8645
# 1310th iteration, loss: 0.6664, test accuracy: 0.8653
# 1320th iteration, loss: 0.4396, test accuracy: 0.8659
# 1330th iteration, loss: 0.4527, test accuracy: 0.8653
# 1340th iteration, loss: 0.5033, test accuracy: 0.8660
# 1350th iteration, loss: 0.4013, test accuracy: 0.8661
# 1360th iteration, loss: 0.7196, test accuracy: 0.8672
# 1370th iteration, loss: 0.5191, test accuracy: 0.8681
# 1380th iteration, loss: 0.6145, test accuracy: 0.8682
# 1390th iteration, loss: 0.5432, test accuracy: 0.8677
# 1400th iteration, loss: 0.5232, test accuracy: 0.8697
# 1410th iteration, loss: 0.4626, test accuracy: 0.8709
# 1420th iteration, loss: 0.5068, test accuracy: 0.8704
# 1430th iteration, loss: 0.5193, test accuracy: 0.8713
# 1440th iteration, loss: 0.5363, test accuracy: 0.8714
# 1450th iteration, loss: 0.5648, test accuracy: 0.8725
# 1460th iteration, loss: 0.6415, test accuracy: 0.8731
# 1470th iteration, loss: 0.5021, test accuracy: 0.8734
# 1480th iteration, loss: 0.5371, test accuracy: 0.8745
# 1490th iteration, loss: 0.4565, test accuracy: 0.8746
# 1500th iteration, loss: 0.5583, test accuracy: 0.8742
# 1510th iteration, loss: 0.5012, test accuracy: 0.8747
# 1520th iteration, loss: 0.5330, test accuracy: 0.8744
# 1530th iteration, loss: 0.5690, test accuracy: 0.8750
# 1540th iteration, loss: 0.4961, test accuracy: 0.8757
# 1550th iteration, loss: 0.6068, test accuracy: 0.8768
# 1560th iteration, loss: 0.5419, test accuracy: 0.8763
# 1570th iteration, loss: 0.4222, test accuracy: 0.8767
# 1580th iteration, loss: 0.4924, test accuracy: 0.8780
# 1590th iteration, loss: 0.5079, test accuracy: 0.8775
# 1600th iteration, loss: 0.5572, test accuracy: 0.8779
# 1610th iteration, loss: 0.4724, test accuracy: 0.8777
# 1620th iteration, loss: 0.4576, test accuracy: 0.8790
# 1630th iteration, loss: 0.5315, test accuracy: 0.8791
# 1640th iteration, loss: 0.4536, test accuracy: 0.8792
# 1650th iteration, loss: 0.4826, test accuracy: 0.8803
# 1660th iteration, loss: 0.5559, test accuracy: 0.8798
# 1670th iteration, loss: 0.6509, test accuracy: 0.8791
# 1680th iteration, loss: 0.5668, test accuracy: 0.8810
# 1690th iteration, loss: 0.5300, test accuracy: 0.8817
# 1700th iteration, loss: 0.6332, test accuracy: 0.8805
# 1710th iteration, loss: 0.4471, test accuracy: 0.8811
# 1720th iteration, loss: 0.3959, test accuracy: 0.8811
# 1730th iteration, loss: 0.5231, test accuracy: 0.8816
# 1740th iteration, loss: 0.5462, test accuracy: 0.8818
# 1750th iteration, loss: 0.5037, test accuracy: 0.8821
# 1760th iteration, loss: 0.5504, test accuracy: 0.8814
# 1770th iteration, loss: 0.3908, test accuracy: 0.8821
# 1780th iteration, loss: 0.5600, test accuracy: 0.8822
# 1790th iteration, loss: 0.5778, test accuracy: 0.8832
# 1800th iteration, loss: 0.5070, test accuracy: 0.8824
# 1810th iteration, loss: 0.6756, test accuracy: 0.8832
# 1820th iteration, loss: 0.4292, test accuracy: 0.8839
# 1830th iteration, loss: 0.3524, test accuracy: 0.8831
# 1840th iteration, loss: 0.5165, test accuracy: 0.8840
# 1850th iteration, loss: 0.5104, test accuracy: 0.8846
# 1860th iteration, loss: 0.4390, test accuracy: 0.8847
# 1870th iteration, loss: 0.5666, test accuracy: 0.8857
# 1880th iteration, loss: 0.4289, test accuracy: 0.8859
# 1890th iteration, loss: 0.3123, test accuracy: 0.8852
# 1900th iteration, loss: 0.3545, test accuracy: 0.8863
# 1910th iteration, loss: 0.4858, test accuracy: 0.8869
# 1920th iteration, loss: 0.4376, test accuracy: 0.8865
# 1930th iteration, loss: 0.5293, test accuracy: 0.8865
# 1940th iteration, loss: 0.4087, test accuracy: 0.8865
# 1950th iteration, loss: 0.4315, test accuracy: 0.8876
# 1960th iteration, loss: 0.3792, test accuracy: 0.8871
# 1970th iteration, loss: 0.5650, test accuracy: 0.8872
# 1980th iteration, loss: 0.5082, test accuracy: 0.8889
# 1990th iteration, loss: 0.4940, test accuracy: 0.8884
# 2000th iteration, loss: 0.3206, test accuracy: 0.8883
